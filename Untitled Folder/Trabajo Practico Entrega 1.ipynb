# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# Lectura del Dataset

# %%
df = pd.read_csv('Dataset/AEP_hourly.csv', sep=',')

# %%
df
# Out:
#                    Datetime   AEP_MW
# 0       2004-12-31 01:00:00  13478.0
# 1       2004-12-31 02:00:00  12865.0
# 2       2004-12-31 03:00:00  12577.0
# 3       2004-12-31 04:00:00  12517.0
# 4       2004-12-31 05:00:00  12670.0
# ...                     ...      ...
# 121268  2018-01-01 20:00:00  21089.0
# 121269  2018-01-01 21:00:00  20999.0
# 121270  2018-01-01 22:00:00  20820.0
# 121271  2018-01-01 23:00:00  20415.0
# 121272  2018-01-02 00:00:00  19993.0
#
# [121273 rows x 2 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(26,5))

# %%
plt.rcParams["figure.figsize"] = (20,5)
ax = df.plot(x="Datetime",y='AEP_MW',rot=90)
ax.set_ylabel("Consumo total en megawatts", fontsize=16)
ax.set_xlabel("Fecha", fontsize=16)
ax.set_title("Consumo de electricidad de la proveedora de energia American Electric Power Company, Inc ")
# Out:
# Text(0.5, 1.0, 'Consumo de electricidad de la proveedora de energia American Electric Power Company, Inc ')

# %%
df["Datetime2"] = pd.to_datetime(df["Datetime"])

# %%
df = df[df["Datetime2"]>=datetime.datetime(2015, 1, 1)]
df = df[df["Datetime2"]<=datetime.datetime(2018, 12, 31)]

# %%
plt.rcParams["figure.figsize"] = (20,5)
ax = df.plot.scatter(x="Datetime",y='AEP_MW',rot=90)
ax.set_ylabel("Consumo total en megawatts", fontsize=16)
ax.set_xlabel("Fecha", fontsize=16)
ax.set_title("Consumo de electricidad de la proveedora de energia American Electric Power Company, Inc ")
# Out:
# Text(0.5, 1.0, 'Consumo de electricidad de la proveedora de energia American Electric Power Company, Inc ')
# Error in callback <function _draw_all_if_interactive at 0x00000287805C5BD0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\miniconda3\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\miniconda3\lib\site-packages\matplotlib\backend_bases.py:2078, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2076 if not self._is_idle_drawing:
# ...

# %%
fig, ax = plt.subplots(4,1,figsize=(26,5))
for i in range(1):
    dfx = df[df["Datetime2"]>=datetime.datetime(2015+i, 1, 1)]
    dfx = dfx[dfx["Datetime2"]<=datetime.datetime(2015+i, 12, 31)]
    ax[i] = dfx.plot.scatter(x="Datetime2",y='AEP_MW',rot=90)
    ax[i].set_ylabel("Consumo total en megawatts", fontsize=16)
    ax[i].set_xlabel("Fecha", fontsize=16)
    ax[i].set_title("Consumo de electricidad del año "+str(2015+i)+" de la proveedora de energia American Electric Power Company, Inc ")

# %%
df["Date"]=df["Datetime2"].dt.date

# %%
df2 = df.groupby(["Date"]).agg({'AEP_MW': [np.max]})

# %%
df2["Date2"] = df2.index

# %%
df2
# Out:
#              AEP_MW       Date2
#                amax
# Date
# 2015-01-01  16662.0  2015-01-01
# 2015-01-02  16662.0  2015-01-02
# 2015-01-03  15701.0  2015-01-03
# 2015-01-04  16027.0  2015-01-04
# 2015-01-05  20225.0  2015-01-05
# ...             ...         ...
# 2018-07-30  18262.0  2018-07-30
# 2018-07-31  16984.0  2018-07-31
# 2018-08-01  17204.0  2018-08-01
# 2018-08-02  18869.0  2018-08-02
# 2018-08-03  14809.0  2018-08-03
#
# [1311 rows x 2 columns]

# %%
fig, ax = plt.subplots(4,1,figsize=(26,5))
for i in range(4):
    dfx = df2[df2["Date2"]>=datetime.date(2015+i, 1, 1)]
    dfx = dfx[dfx["Date2"]<=datetime.date(2015+i, 12, 31)]
    ax[i] = dfx.plot(x="Date2",y='AEP_MW',rot=90)
    ax[i].set_ylabel("Consumo total en megawatts", fontsize=16)
    ax[i].set_xlabel("Fecha", fontsize=16)
    ax[i].set_title("Consumo de electricidad del año "+str(2015+i)+" de la proveedora de energia American Electric Power Company, Inc ")
